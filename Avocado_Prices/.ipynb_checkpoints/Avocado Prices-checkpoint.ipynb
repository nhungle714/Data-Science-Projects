# %% [markdown]
# Tim Gurner, an Australian millionaire and property mogul, advised millenials not to drink Starbucks nor to eat avocado toasts should they want to purchase a house. I like avocado toasts, so it is interesting to see whether the avocado prices fluctuate across different regions in the US, so that I may move to a region with lower avocado prices so I can continue eating avocado toasts without any guilts.
#
# This data set is from Hass Avocado Board (http://www.hassavocadoboard.com/retail/volume-and-price-data) that records average prices of conventional and organic avocado in different regions from December 2014 to April 2018. The goal of this exercise is to forecast avocado prices in different regions given historical average avocado prices by region and by type (i.e., conventional vs. organic).

# %% [markdown]
# The key takeaways from this exercise include:

# %% [markdown]
# **1. Prophet for forecasting time series data**
#
# Prophet is open source software released by Facebook's Core Data Science team. It is used to forecast time series with data based on an additive model where non-linear trends are fit with seasonality and holiday effects. Since avocado is an agricultural product and should have strong seasonal effects with a lot of historical data, it is reasonable to use Prophet to predict futre prices of avocado.

# %% [markdown]
# **2. Increasing avocado prices**
#
# In general, regardless of seasonal effects, avocado prices have increased strongly from late 2017 to mid 2018. It is because the California avocado harvests are down by 44% due to changes in weather while the demand for avocado is constantly high with the wide media coverage on benefits of avocados.

# %% [markdown]
# **3. Avocado prices vary greatly by region**
#
# Prices of avocado vary significantly by region. For example, organic avocados, on average, are cheaper than ones in San Diego and will continue getting cheaper.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import sklearn
import statsmodels.api as sm

# %%
avocado = pd.read_csv('avocado.csv')

# %%
avocado.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# ## 1. Trend - Avocado Average Prices by Type Overtime

# %%
avocado['Date'] = pd.to_datetime(avocado['Date'])

# %%
plt.figure(figsize=(16, 10))
sns.lineplot(x = 'Date', y = 'AveragePrice', data = avocado, hue = 'type')
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
avocado.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %% [markdown]
# ## 2. Trend: Avocado Prices Distribution by Region and Year

# %% [markdown]
# ### 2.1. Conventional Avocado

# %%
conventional_2018_order = (avocado[(avocado['year'] == 2018) & (avocado['type'] == 'conventional')]
 .groupby(['region']).agg({'AveragePrice': 'mean'})
 .reset_index().sort_values(by=['AveragePrice']).region)

# %%
plt.figure(figsize=(20, 16))
sns.factorplot(x='AveragePrice', 
               y='region', 
               data=avocado.query('type == "conventional"'), 
               hue='year',
               size=8,
               aspect=0.6,
               order = conventional_2018_order,
               join=False )
plt.title("Conventional Avocado Average Prices by Region and Year")
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 2.2. Organic Avocado

# %%
organic_2018_order = (avocado[(avocado['year']==2018) & (avocado['type']=='organic')]
                     .groupby(['region']).agg({'AveragePrice': 'mean'}).reset_index()
                     .sort_values(by=['AveragePrice']).region)

# %%
plt.figure(figsize=(16, 10))
sns.factorplot(x='AveragePrice', y='region', data=avocado.query('type == "organic"'), hue='year',
              size=8, aspect=0.6, order = organic_2018_order, join=False)
plt.title('Organice Avocado Average Prices by Region and Year')
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 3. Seasonality Effects

# %%
avocado['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
avocado['Month'] = avocado['Date'].apply(lambda x: x.month)

# %%
conventional_ny = avocado[(avocado['region']=="NewYork")]

# %%
ax = sns.factorplot(x='Month', y='AveragePrice', 
               data=avocado[(avocado['region']=="NewYork")], 
              hue='year', row='type',
              size=5, aspect=2)
ax.fig.suptitle('New York Average Avocado Prices over Month over Year')
ax.fig.subplots_adjust(top=0.9)
#ax.set_titles('')
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.factorplot(x='Month', y='AveragePrice', 
               data=avocado[(avocado['region']=="Chicago")], 
              hue='year', row='type',
              size=5, aspect=2)
ax.fig.suptitle('Chicago Average Avocado Prices over Month over Year')
ax.fig.subplots_adjust(top=0.9)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.factorplot(x='Month', y='AveragePrice', 
               data=avocado[(avocado['region']=="California")], 
              hue='year', row='type',
              size=5, aspect=2)
ax.fig.suptitle('California Average Avocado Prices over Month over Year')
ax.fig.subplots_adjust(top=0.9)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 4. Forecasting

# %%
# https://towardsdatascience.com/a-quick-start-of-time-series-forecasting-with-a-practical-example-using-fb-prophet-31c4447a2274

# %%
organic_totalUS = (avocado.query('region == "TotalUS"').query('type == "organic"')
.rename(columns = {'Date': 'ds', 'AveragePrice': 'y'}))

# %%
from fbprophet import Prophet

# %%
m1 = Prophet(interval_width=0.95, yearly_seasonality=True, changepoint_prior_scale=1)
m1.add_country_holidays(country_name='US')
m1.add_seasonality(name='monthly', period=12, fourier_order=5, prior_scale=0.02)
m1.fit(organic_totalUS)
future = m1.make_future_dataframe(periods=10, freq="M")
forecast = m1.predict(future)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.7/site-packages/pystan/misc.py:399: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.

# %%
us_holidays = m.train_holiday_names

# %%
fig1 = m1.plot(forecast)
axes = fig1.get_axes()
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Change')
axes[0].set_ylim([0, 3])
plt.title('Total US Organic Avocado Average Prices - Monthly and Yearly seasonality')
plt.show()

# %%
m2 = Prophet()
m2.fit(organic_totalUS)
future = m2.make_future_dataframe(periods=365)
forecast = m2.predict(future)
#forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
fig2 = m2.plot(forecast)
axes = fig2.get_axes()
axes[0].set_ylabel("Change")
axes[0].set_xlabel("Date")
plt.title('Total US Organic Avocado Average Prices - No seasonality effect')
plt.show()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fig3 = m1.plot_components(forecast)
axes=fig3.get_axes()
axes[0].set_xlabel("Date")
axes[1].set_xlabel("Holiday Date")
axes[2].set_xlabel("Day of Year")
axes[3].set_xlabel("Day of Month")
plt.show()

# %%
def avocado_region(region, avocado_type): 
    df = avocado[(avocado['type'] == avocado_type)  & (avocado['region'] == region)][['Date','AveragePrice']]
    df = df.rename(columns = {'Date': 'ds', 'AveragePrice': 'y'})
    m = Prophet()
    m.fit(df)
    future = m.make_future_dataframe(periods=365)
    #future.tail()
    forecast = m.predict(future)
    #forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
    fig1 = m.plot(forecast)
    plt.title('{} Avocado Prices in {}'.format(avocado_type, region))
    plt.show()

# %%
avocado_region('NewYork', 'conventional')
avocado_region('NewYork', 'organic')
avocado_region('Boston', 'organic')
avocado_region('California', 'organic')
avocado_region('Chicago', 'organic')
avocado_region('Chicago', 'conventional')
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# ...
