# %% [markdown]
# **Note:**
# This note book is to provide a general structure of the project and responsibility distribution

# %%
from sklearn.base import BaseEstimator, RegressorMixin
from scipy.optimize import minimize
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_squared_error, make_scorer
import pandas as pd
import random
from collections import Counter

from random import shuffle
import os

# %% [markdown]
# ## Load Data

# %%
#os.listdir('/Users/NhungLe/Box Sync/Free/Data-Science-Projects/Breast Cancer Diagnosis/Raw Data/')

# %%
path = '/Users/NhungLe/Box Sync/Free/Data-Science-Projects/Breast Cancer Diagnosis/Raw Data/'

# %%
files = ['calc_case_description_train_set.csv', 'mass_case_description_train_set.csv',
        'calc_case_description_test_set.csv','mass_case_description_test_set.csv' ]

# %%
dataframes = {}
for file in files:
    name_l = file.split('_')
    f_name = str(name_l[0]) + '_' + str(name_l[3])
    df = pd.read_csv(path + file)
    dataframes[f_name] = df

# %%
# cal_train = pd.read_csv(path + 'calc_case_description_train_set.csv')
# cal_test = pd.read_csv(path + 'calc_case_description_test_set.csv')
# mass_train = pd.read_csv(path + 'mass_case_description_train_set.csv')
# mass_test = pd.read_csv(path + 'mass_case_description_test_set.csv')

# %%
for key in dataframes.keys(): 
    df = dataframes[key]
    print('Shape of {} is {}'.format(key, df.shape))
    print('Number of patients from {} is {}'.format(key, df['patient_id'].nunique() ))
# Out:
# Shape of calc_train is (1546, 14)
# Number of patients from calc_train is 602
# Shape of mass_train is (1318, 14)
# Number of patients from mass_train is 691
# Shape of calc_test is (326, 14)
# Number of patients from calc_test is 151
# Shape of mass_test is (378, 14)
# Number of patients from mass_test is 201

# %%
print(1)

# %%
columns = ['image view', 'abnormality id', 'abnormality type', 'calc type', 'calc distribution', 'assessment', 'pathology',
      'subtlety']

# %%
for col in columns: 
    print('---------------')
    print('Unique values of column {}'.format(col))
    print(cal_train_desc[col].value_counts())
# Out:
# ---------------
# Unique values of column image view
# MLO    807
# CC     739
# Name: image view, dtype: int64
# ---------------
# Unique values of column abnormality id
# 1    1172
# 2     219
# 3      88
# 4      35
# 5      20
# 6      10
# 7       2
# Name: abnormality id, dtype: int64
# ---------------
# Unique values of column abnormality type
# calcification    1546
# Name: abnormality type, dtype: int64
# ---------------
# Unique values of column calc type
# PLEOMORPHIC                                                 664
# AMORPHOUS                                                   138
# PUNCTATE                                                    106
# LUCENT_CENTER                                                93
# VASCULAR                                                     82
# FINE_LINEAR_BRANCHING                                        77
# COARSE                                                       35
# ROUND_AND_REGULAR-LUCENT_CENTER                              31
# PLEOMORPHIC-FINE_LINEAR_BRANCHING                            28
# ROUND_AND_REGULAR-LUCENT_CENTER-PUNCTATE                     24
# ROUND_AND_REGULAR-EGGSHELL                                   23
# PUNCTATE-PLEOMORPHIC                                         21
# DYSTROPHIC                                                   20
# LUCENT_CENTERED                                              18
# ROUND_AND_REGULAR                                            17
# ROUND_AND_REGULAR-LUCENT_CENTERED                            14
# AMORPHOUS-PLEOMORPHIC                                        12
# LARGE_RODLIKE-ROUND_AND_REGULAR                              11
# PUNCTATE-AMORPHOUS                                           10
# COARSE-ROUND_AND_REGULAR-LUCENT_CENTER                       10
# LUCENT_CENTER-PUNCTATE                                        8
# VASCULAR-COARSE-LUCENT_CENTERED                               8
# ROUND_AND_REGULAR-PLEOMORPHIC                                 7
# EGGSHELL                                                      7
# VASCULAR-COARSE                                               6
# PUNCTATE-FINE_LINEAR_BRANCHING                                6
# ROUND_AND_REGULAR-PUNCTATE                                    5
# LARGE_RODLIKE                                                 4
# SKIN-PUNCTATE-ROUND_AND_REGULAR                               4
# SKIN-PUNCTATE                                                 4
# COARSE-ROUND_AND_REGULAR-LUCENT_CENTERED                      4
# PUNCTATE-ROUND_AND_REGULAR                                    4
# AMORPHOUS-ROUND_AND_REGULAR                                   3
# PUNCTATE-LUCENT_CENTER                                        3
# MILK_OF_CALCIUM                                               2
# ROUND_AND_REGULAR-PUNCTATE-AMORPHOUS                          2
# COARSE-ROUND_AND_REGULAR                                      2
# COARSE-LUCENT_CENTER                                          2
# VASCULAR-COARSE-LUCENT_CENTER-ROUND_AND_REGULAR-PUNCTATE      2
# COARSE-PLEOMORPHIC                                            2
# ROUND_AND_REGULAR-LUCENT_CENTER-DYSTROPHIC                    2
# SKIN                                                          2
# SKIN-COARSE-ROUND_AND_REGULAR                                 1
# ROUND_AND_REGULAR-AMORPHOUS                                   1
# PLEOMORPHIC-PLEOMORPHIC                                       1
# Name: calc type, dtype: int64
# ---------------
# Unique values of column calc distribution
# CLUSTERED              740
# SEGMENTAL              168
# REGIONAL                99
# LINEAR                  90
# DIFFUSELY_SCATTERED     37
# CLUSTERED-LINEAR        25
# CLUSTERED-SEGMENTAL      5
# LINEAR-SEGMENTAL         5
# REGIONAL-REGIONAL        1
# Name: calc distribution, dtype: int64
# ---------------
# Unique values of column assessment
# 4    753
# 2    482
# 5    159
# 3     89
# 0     63
# Name: assessment, dtype: int64
# ---------------
# Unique values of column pathology
# MALIGNANT                  544
# BENIGN                     528
# BENIGN_WITHOUT_CALLBACK    474
# Name: pathology, dtype: int64
# ---------------
# Unique values of column subtlety
# 3    502
# 5    361
# 4    346
# 2    242
# 1     95
# Name: subtlety, dtype: int64

# %%
# Some patients have more than 1 pathology
multi_path_cal = cal_train_desc.groupby('patient_id').filter(lambda x: x['pathology'].nunique() > 1)

# %%
multi_path_cal
# Out:
#      patient_id  breast density left or right breast image view  \
# 293     P_00418               3                RIGHT        MLO
# 292     P_00418               3                RIGHT         CC
# 290     P_00418               3                 LEFT         CC
# 291     P_00418               3                 LEFT        MLO
# 329     P_00467               3                 LEFT         CC
# 330     P_00467               3                 LEFT        MLO
# 331     P_00467               3                RIGHT         CC
# 332     P_00467               3                RIGHT        MLO
# 447     P_00557               2                RIGHT        MLO
# 445     P_00557               2                RIGHT        MLO
# 444     P_00557               2                RIGHT         CC
# 443     P_00557               2                RIGHT         CC
# 446     P_00557               2                RIGHT        MLO
# 441     P_00557               2                RIGHT         CC
# 440     P_00557               2                 LEFT        MLO
# 439     P_00557               2                 LEFT         CC
# 442     P_00557               2                RIGHT         CC
# 485     P_00600               3                 LEFT        MLO
# 484     P_00600               3                 LEFT        MLO
# 483     P_00600               3                 LEFT         CC
# 482     P_00600               3                 LEFT         CC
# 679     P_00858               3                 LEFT         CC
# 680     P_00858               3                 LEFT        MLO
# 681     P_00858               3                RIGHT         CC
# 682     P_00858               3                RIGHT         CC
# 683     P_00858               3                RIGHT        MLO
# 684     P_00858               3                RIGHT        MLO
# 735     P_00937               3                 LEFT         CC
# 736     P_00937               3                 LEFT        MLO
# 737     P_00937               3                RIGHT         CC
# ...         ...             ...                  ...        ...
# 779     P_00992               3                RIGHT        MLO
# 899     P_01156               3                 LEFT         CC
# 900     P_01156               3                 LEFT        MLO
# 901     P_01156               3                RIGHT         CC
# 902     P_01156               3                RIGHT        MLO
# 940     P_01200               3                RIGHT        MLO
# 938     P_01200               3                 LEFT         CC
# 939     P_01200               3                 LEFT        MLO
# 981     P_01276               3                 LEFT         CC
# 982     P_01276               3                 LEFT        MLO
# 983     P_01276               3                RIGHT         CC
# 984     P_01276               3                RIGHT         CC
# 985     P_01276               3                RIGHT        MLO
# 986     P_01276               3                RIGHT        MLO
# 987     P_01284               3                RIGHT        MLO
# 988     P_01284               3                RIGHT        MLO
# 1101    P_01409               2                 LEFT         CC
# 1102    P_01409               2                 LEFT         CC
# 1103    P_01409               2                 LEFT        MLO
# 1104    P_01409               2                 LEFT        MLO
# 1105    P_01409               2                RIGHT         CC
# 1106    P_01409               2                RIGHT        MLO
# 1244    P_01582               2                RIGHT         CC
# 1245    P_01582               2                RIGHT        MLO
# 1243    P_01582               2                 LEFT        MLO
# 1242    P_01582               2                 LEFT         CC
# 1385    P_01819               2                 LEFT        MLO
# 1383    P_01819               2                 LEFT         CC
# 1384    P_01819               2                 LEFT         CC
# 1386    P_01819               2                 LEFT        MLO
#
#       abnormality id abnormality type                          calc type  \
# 293                1    calcification           COARSE-ROUND_AND_REGULAR
# 292                1    calcification           COARSE-ROUND_AND_REGULAR
# 290                1    calcification                        PLEOMORPHIC
# 291                1    calcification                        PLEOMORPHIC
# 329                1    calcification                             COARSE
# 330                1    calcification                             COARSE
# 331                1    calcification                        PLEOMORPHIC
# 332                1    calcification                        PLEOMORPHIC
# 447                3    calcification                        PLEOMORPHIC
# 445                1    calcification                        PLEOMORPHIC
# 444                4    calcification                        PLEOMORPHIC
# 443                3    calcification                        PLEOMORPHIC
# 446                2    calcification                        PLEOMORPHIC
# 441                1    calcification                        PLEOMORPHIC
# 440                1    calcification                        PLEOMORPHIC
# 439                1    calcification                        PLEOMORPHIC
# 442                2    calcification                        PLEOMORPHIC
# 485                2    calcification                          AMORPHOUS
# 484                1    calcification                          AMORPHOUS
# 483                2    calcification                          AMORPHOUS
# 482                1    calcification                          AMORPHOUS
# 679                1    calcification                    LUCENT_CENTERED
# 680                1    calcification                    LUCENT_CENTERED
# 681                1    calcification                        PLEOMORPHIC
# 682                2    calcification                           PUNCTATE
# 683                1    calcification                           PUNCTATE
# 684                2    calcification                        PLEOMORPHIC
# 735                1    calcification                        PLEOMORPHIC
# 736                1    calcification                        PLEOMORPHIC
# 737                1    calcification                          AMORPHOUS
# ...              ...              ...                                ...
# 779                1    calcification              FINE_LINEAR_BRANCHING
# 899                1    calcification                           PUNCTATE
# 900                1    calcification                           PUNCTATE
# 901                1    calcification  PLEOMORPHIC-FINE_LINEAR_BRANCHING
# 902                1    calcification                        PLEOMORPHIC
# 940                1    calcification                        PLEOMORPHIC
# 938                1    calcification                             COARSE
# 939                1    calcification                             COARSE
# 981                1    calcification                         DYSTROPHIC
# 982                1    calcification                         DYSTROPHIC
# 983                1    calcification                          AMORPHOUS
# 984                2    calcification                        PLEOMORPHIC
# 985                1    calcification                          AMORPHOUS
# 986                2    calcification                        PLEOMORPHIC
# 987                1    calcification                        PLEOMORPHIC
# 988                2    calcification                          AMORPHOUS
# 1101               1    calcification                        PLEOMORPHIC
# 1102               2    calcification                        PLEOMORPHIC
# 1103               1    calcification                        PLEOMORPHIC
# 1104               2    calcification                        PLEOMORPHIC
# 1105               1    calcification                           VASCULAR
# 1106               1    calcification                           VASCULAR
# 1244               1    calcification                          AMORPHOUS
# 1245               1    calcification                          AMORPHOUS
# 1243               1    calcification                          AMORPHOUS
# 1242               1    calcification                          AMORPHOUS
# 1385               1    calcification                        PLEOMORPHIC
# 1383               1    calcification                        PLEOMORPHIC
# 1384               2    calcification                           EGGSHELL
# 1386               2    calcification                           EGGSHELL
#
#      calc distribution  assessment                pathology  subtlety  \
# 293                NaN           2  BENIGN_WITHOUT_CALLBACK         4
# 292                NaN           2  BENIGN_WITHOUT_CALLBACK         4
# 290          CLUSTERED           4                MALIGNANT         2
# 291          CLUSTERED           4                MALIGNANT         2
# 329                NaN           2  BENIGN_WITHOUT_CALLBACK         3
# 330                NaN           2  BENIGN_WITHOUT_CALLBACK         3
# 331          CLUSTERED           4                MALIGNANT         3
# 332          CLUSTERED           4                MALIGNANT         3
# 447          CLUSTERED           2  BENIGN_WITHOUT_CALLBACK         4
# 445          CLUSTERED           2  BENIGN_WITHOUT_CALLBACK         4
# 444          CLUSTERED           2  BENIGN_WITHOUT_CALLBACK         4
# 443          CLUSTERED           2  BENIGN_WITHOUT_CALLBACK         4
# 446          CLUSTERED           2  BENIGN_WITHOUT_CALLBACK         4
# 441          CLUSTERED           2  BENIGN_WITHOUT_CALLBACK         4
# 440          CLUSTERED           4                   BENIGN         3
# 439          CLUSTERED           4                   BENIGN         3
# 442          CLUSTERED           2  BENIGN_WITHOUT_CALLBACK         4
# 485          CLUSTERED           4                MALIGNANT         1
# 484          CLUSTERED           4                   BENIGN         1
# 483          CLUSTERED           4                MALIGNANT         1
# 482          CLUSTERED           4                   BENIGN         1
# 679                NaN           2  BENIGN_WITHOUT_CALLBACK         5
# 680                NaN           2  BENIGN_WITHOUT_CALLBACK         5
# 681          CLUSTERED           4                   BENIGN         4
# 682          CLUSTERED           3  BENIGN_WITHOUT_CALLBACK         4
# 683          CLUSTERED           3  BENIGN_WITHOUT_CALLBACK         4
# 684          CLUSTERED           4                   BENIGN         4
# 735          SEGMENTAL           5                MALIGNANT         5
# 736          SEGMENTAL           5                MALIGNANT         5
# 737          CLUSTERED           4                MALIGNANT         3
# ...                ...         ...                      ...       ...
# 779          SEGMENTAL           5                MALIGNANT         5
# 899          SEGMENTAL           4                MALIGNANT         2
# 900          SEGMENTAL           4                MALIGNANT         2
# 901          CLUSTERED           4                   BENIGN         3
# 902   CLUSTERED-LINEAR           4                   BENIGN         3
# 940          CLUSTERED           4  BENIGN_WITHOUT_CALLBACK         4
# 938                NaN           2  BENIGN_WITHOUT_CALLBACK         5
# 939                NaN           2                   BENIGN         5
# 981          SEGMENTAL           2  BENIGN_WITHOUT_CALLBACK         5
# 982          SEGMENTAL           2  BENIGN_WITHOUT_CALLBACK         5
# 983          CLUSTERED           4                   BENIGN         3
# 984          SEGMENTAL           3                   BENIGN         3
# 985          CLUSTERED           4                   BENIGN         3
# 986          SEGMENTAL           3                   BENIGN         3
# 987          CLUSTERED           5                MALIGNANT         3
# 988          CLUSTERED           4                   BENIGN         3
# 1101         CLUSTERED           4                   BENIGN         2
# 1102         CLUSTERED           4                   BENIGN         2
# 1103         CLUSTERED           4                   BENIGN         2
# 1104         CLUSTERED           4                   BENIGN         2
# 1105               NaN           2  BENIGN_WITHOUT_CALLBACK         5
# 1106               NaN           2  BENIGN_WITHOUT_CALLBACK         5
# 1244         CLUSTERED           4                   BENIGN         2
# 1245         CLUSTERED           4                   BENIGN         2
# 1243          REGIONAL           5                MALIGNANT         5
# 1242          REGIONAL           5                MALIGNANT         5
# 1385         CLUSTERED           4                MALIGNANT         3
# 1383         CLUSTERED           4                MALIGNANT         2
# 1384         SEGMENTAL           2  BENIGN_WITHOUT_CALLBACK         5
# 1386         SEGMENTAL           2  BENIGN_WITHOUT_CALLBACK         5
#
#                                         image file path  \
# 293   Calc-Training_P_00418_RIGHT_MLO/1.3.6.1.4.1.95...
# 292   Calc-Training_P_00418_RIGHT_CC/1.3.6.1.4.1.959...
# 290   Calc-Training_P_00418_LEFT_CC/1.3.6.1.4.1.9590...
# 291   Calc-Training_P_00418_LEFT_MLO/1.3.6.1.4.1.959...
# 329   Calc-Training_P_00467_LEFT_CC/1.3.6.1.4.1.9590...
# 330   Calc-Training_P_00467_LEFT_MLO/1.3.6.1.4.1.959...
# 331   Calc-Training_P_00467_RIGHT_CC/1.3.6.1.4.1.959...
# 332   Calc-Training_P_00467_RIGHT_MLO/1.3.6.1.4.1.95...
# 447   Calc-Training_P_00557_RIGHT_MLO/1.3.6.1.4.1.95...
# 445   Calc-Training_P_00557_RIGHT_MLO/1.3.6.1.4.1.95...
# 444   Calc-Training_P_00557_RIGHT_CC/1.3.6.1.4.1.959...
# 443   Calc-Training_P_00557_RIGHT_CC/1.3.6.1.4.1.959...
# 446   Calc-Training_P_00557_RIGHT_MLO/1.3.6.1.4.1.95...
# 441   Calc-Training_P_00557_RIGHT_CC/1.3.6.1.4.1.959...
# 440   Calc-Training_P_00557_LEFT_MLO/1.3.6.1.4.1.959...
# 439   Calc-Training_P_00557_LEFT_CC/1.3.6.1.4.1.9590...
# 442   Calc-Training_P_00557_RIGHT_CC/1.3.6.1.4.1.959...
# 485   Calc-Training_P_00600_LEFT_MLO/1.3.6.1.4.1.959...
# 484   Calc-Training_P_00600_LEFT_MLO/1.3.6.1.4.1.959...
# 483   Calc-Training_P_00600_LEFT_CC/1.3.6.1.4.1.9590...
# 482   Calc-Training_P_00600_LEFT_CC/1.3.6.1.4.1.9590...
# 679   Calc-Training_P_00858_LEFT_CC/1.3.6.1.4.1.9590...
# 680   Calc-Training_P_00858_LEFT_MLO/1.3.6.1.4.1.959...
# 681   Calc-Training_P_00858_RIGHT_CC/1.3.6.1.4.1.959...
# 682   Calc-Training_P_00858_RIGHT_CC/1.3.6.1.4.1.959...
# 683   Calc-Training_P_00858_RIGHT_MLO/1.3.6.1.4.1.95...
# 684   Calc-Training_P_00858_RIGHT_MLO/1.3.6.1.4.1.95...
# 735   Calc-Training_P_00937_LEFT_CC/1.3.6.1.4.1.9590...
# 736   Calc-Training_P_00937_LEFT_MLO/1.3.6.1.4.1.959...
# 737   Calc-Training_P_00937_RIGHT_CC/1.3.6.1.4.1.959...
# ...                                                 ...
# 779   Calc-Training_P_00992_RIGHT_MLO/1.3.6.1.4.1.95...
# 899   Calc-Training_P_01156_LEFT_CC/1.3.6.1.4.1.9590...
# 900   Calc-Training_P_01156_LEFT_MLO/1.3.6.1.4.1.959...
# 901   Calc-Training_P_01156_RIGHT_CC/1.3.6.1.4.1.959...
# 902   Calc-Training_P_01156_RIGHT_MLO/1.3.6.1.4.1.95...
# 940   Calc-Training_P_01200_RIGHT_MLO/1.3.6.1.4.1.95...
# 938   Calc-Training_P_01200_LEFT_CC/1.3.6.1.4.1.9590...
# 939   Calc-Training_P_01200_LEFT_MLO/1.3.6.1.4.1.959...
# 981   Calc-Training_P_01276_LEFT_CC/1.3.6.1.4.1.9590...
# 982   Calc-Training_P_01276_LEFT_MLO/1.3.6.1.4.1.959...
# 983   Calc-Training_P_01276_RIGHT_CC/1.3.6.1.4.1.959...
# 984   Calc-Training_P_01276_RIGHT_CC/1.3.6.1.4.1.959...
# 985   Calc-Training_P_01276_RIGHT_MLO/1.3.6.1.4.1.95...
# 986   Calc-Training_P_01276_RIGHT_MLO/1.3.6.1.4.1.95...
# 987   Calc-Training_P_01284_RIGHT_MLO/1.3.6.1.4.1.95...
# 988   Calc-Training_P_01284_RIGHT_MLO/1.3.6.1.4.1.95...
# 1101  Calc-Training_P_01409_LEFT_CC/1.3.6.1.4.1.9590...
# 1102  Calc-Training_P_01409_LEFT_CC/1.3.6.1.4.1.9590...
# 1103  Calc-Training_P_01409_LEFT_MLO/1.3.6.1.4.1.959...
# 1104  Calc-Training_P_01409_LEFT_MLO/1.3.6.1.4.1.959...
# 1105  Calc-Training_P_01409_RIGHT_CC/1.3.6.1.4.1.959...
# 1106  Calc-Training_P_01409_RIGHT_MLO/1.3.6.1.4.1.95...
# 1244  Calc-Training_P_01582_RIGHT_CC/1.3.6.1.4.1.959...
# 1245  Calc-Training_P_01582_RIGHT_MLO/1.3.6.1.4.1.95...
# 1243  Calc-Training_P_01582_LEFT_MLO/1.3.6.1.4.1.959...
# 1242  Calc-Training_P_01582_LEFT_CC/1.3.6.1.4.1.9590...
# 1385  Calc-Training_P_01819_LEFT_MLO/1.3.6.1.4.1.959...
# 1383  Calc-Training_P_01819_LEFT_CC/1.3.6.1.4.1.9590...
# 1384  Calc-Training_P_01819_LEFT_CC/1.3.6.1.4.1.9590...
# 1386  Calc-Training_P_01819_LEFT_MLO/1.3.6.1.4.1.959...
#
#                                 cropped image file path  \
# 293   Calc-Training_P_00418_RIGHT_MLO_1/1.3.6.1.4.1....
# 292   Calc-Training_P_00418_RIGHT_CC_1/1.3.6.1.4.1.9...
# 290   Calc-Training_P_00418_LEFT_CC_1/1.3.6.1.4.1.95...
# 291   Calc-Training_P_00418_LEFT_MLO_1/1.3.6.1.4.1.9...
# 329   Calc-Training_P_00467_LEFT_CC_1/1.3.6.1.4.1.95...
# 330   Calc-Training_P_00467_LEFT_MLO_1/1.3.6.1.4.1.9...
# 331   Calc-Training_P_00467_RIGHT_CC_1/1.3.6.1.4.1.9...
# 332   Calc-Training_P_00467_RIGHT_MLO_1/1.3.6.1.4.1....
# 447   Calc-Training_P_00557_RIGHT_MLO_3/1.3.6.1.4.1....
# 445   Calc-Training_P_00557_RIGHT_MLO_1/1.3.6.1.4.1....
# 444   Calc-Training_P_00557_RIGHT_CC_4/1.3.6.1.4.1.9...
# 443   Calc-Training_P_00557_RIGHT_CC_3/1.3.6.1.4.1.9...
# 446   Calc-Training_P_00557_RIGHT_MLO_2/1.3.6.1.4.1....
# 441   Calc-Training_P_00557_RIGHT_CC_1/1.3.6.1.4.1.9...
# 440   Calc-Training_P_00557_LEFT_MLO_1/1.3.6.1.4.1.9...
# 439   Calc-Training_P_00557_LEFT_CC_1/1.3.6.1.4.1.95...
# 442   Calc-Training_P_00557_RIGHT_CC_2/1.3.6.1.4.1.9...
# 485   Calc-Training_P_00600_LEFT_MLO_2/1.3.6.1.4.1.9...
# 484   Calc-Training_P_00600_LEFT_MLO_1/1.3.6.1.4.1.9...
# 483   Calc-Training_P_00600_LEFT_CC_2/1.3.6.1.4.1.95...
# 482   Calc-Training_P_00600_LEFT_CC_1/1.3.6.1.4.1.95...
# 679   Calc-Training_P_00858_LEFT_CC_1/1.3.6.1.4.1.95...
# 680   Calc-Training_P_00858_LEFT_MLO_1/1.3.6.1.4.1.9...
# 681   Calc-Training_P_00858_RIGHT_CC_1/1.3.6.1.4.1.9...
# 682   Calc-Training_P_00858_RIGHT_CC_2/1.3.6.1.4.1.9...
# 683   Calc-Training_P_00858_RIGHT_MLO_1/1.3.6.1.4.1....
# 684   Calc-Training_P_00858_RIGHT_MLO_2/1.3.6.1.4.1....
# 735   Calc-Training_P_00937_LEFT_CC_1/1.3.6.1.4.1.95...
# 736   Calc-Training_P_00937_LEFT_MLO_1/1.3.6.1.4.1.9...
# 737   Calc-Training_P_00937_RIGHT_CC_1/1.3.6.1.4.1.9...
# ...                                                 ...
# 779   Calc-Training_P_00992_RIGHT_MLO_1/1.3.6.1.4.1....
# 899   Calc-Training_P_01156_LEFT_CC_1/1.3.6.1.4.1.95...
# 900   Calc-Training_P_01156_LEFT_MLO_1/1.3.6.1.4.1.9...
# 901   Calc-Training_P_01156_RIGHT_CC_1/1.3.6.1.4.1.9...
# 902   Calc-Training_P_01156_RIGHT_MLO_1/1.3.6.1.4.1....
# 940   Calc-Training_P_01200_RIGHT_MLO_1/1.3.6.1.4.1....
# 938   Calc-Training_P_01200_LEFT_CC_1/1.3.6.1.4.1.95...
# 939   Calc-Training_P_01200_LEFT_MLO_1/1.3.6.1.4.1.9...
# 981   Calc-Training_P_01276_LEFT_CC_1/1.3.6.1.4.1.95...
# 982   Calc-Training_P_01276_LEFT_MLO_1/1.3.6.1.4.1.9...
# 983   Calc-Training_P_01276_RIGHT_CC_1/1.3.6.1.4.1.9...
# 984   Calc-Training_P_01276_RIGHT_CC_2/1.3.6.1.4.1.9...
# 985   Calc-Training_P_01276_RIGHT_MLO_1/1.3.6.1.4.1....
# 986   Calc-Training_P_01276_RIGHT_MLO_2/1.3.6.1.4.1....
# 987   Calc-Training_P_01284_RIGHT_MLO_1/1.3.6.1.4.1....
# 988   Calc-Training_P_01284_RIGHT_MLO_2/1.3.6.1.4.1....
# 1101  Calc-Training_P_01409_LEFT_CC_1/1.3.6.1.4.1.95...
# 1102  Calc-Training_P_01409_LEFT_CC_2/1.3.6.1.4.1.95...
# 1103  Calc-Training_P_01409_LEFT_MLO_1/1.3.6.1.4.1.9...
# 1104  Calc-Training_P_01409_LEFT_MLO_2/1.3.6.1.4.1.9...
# 1105  Calc-Training_P_01409_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1106  Calc-Training_P_01409_RIGHT_MLO_1/1.3.6.1.4.1....
# 1244  Calc-Training_P_01582_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1245  Calc-Training_P_01582_RIGHT_MLO_1/1.3.6.1.4.1....
# 1243  Calc-Training_P_01582_LEFT_MLO_1/1.3.6.1.4.1.9...
# 1242  Calc-Training_P_01582_LEFT_CC_1/1.3.6.1.4.1.95...
# 1385  Calc-Training_P_01819_LEFT_MLO_1/1.3.6.1.4.1.9...
# 1383  Calc-Training_P_01819_LEFT_CC_1/1.3.6.1.4.1.95...
# 1384  Calc-Training_P_01819_LEFT_CC_2/1.3.6.1.4.1.95...
# 1386  Calc-Training_P_01819_LEFT_MLO_2/1.3.6.1.4.1.9...
#
#                                      ROI mask file path
# 293   Calc-Training_P_00418_RIGHT_MLO_1/1.3.6.1.4.1....
# 292   Calc-Training_P_00418_RIGHT_CC_1/1.3.6.1.4.1.9...
# 290   Calc-Training_P_00418_LEFT_CC_1/1.3.6.1.4.1.95...
# 291   Calc-Training_P_00418_LEFT_MLO_1/1.3.6.1.4.1.9...
# 329   Calc-Training_P_00467_LEFT_CC_1/1.3.6.1.4.1.95...
# 330   Calc-Training_P_00467_LEFT_MLO_1/1.3.6.1.4.1.9...
# 331   Calc-Training_P_00467_RIGHT_CC_1/1.3.6.1.4.1.9...
# 332   Calc-Training_P_00467_RIGHT_MLO_1/1.3.6.1.4.1....
# 447   Calc-Training_P_00557_RIGHT_MLO_3/1.3.6.1.4.1....
# 445   Calc-Training_P_00557_RIGHT_MLO_1/1.3.6.1.4.1....
# 444   Calc-Training_P_00557_RIGHT_CC_4/1.3.6.1.4.1.9...
# 443   Calc-Training_P_00557_RIGHT_CC_3/1.3.6.1.4.1.9...
# 446   Calc-Training_P_00557_RIGHT_MLO_2/1.3.6.1.4.1....
# 441   Calc-Training_P_00557_RIGHT_CC_1/1.3.6.1.4.1.9...
# 440   Calc-Training_P_00557_LEFT_MLO_1/1.3.6.1.4.1.9...
# 439   Calc-Training_P_00557_LEFT_CC_1/1.3.6.1.4.1.95...
# 442   Calc-Training_P_00557_RIGHT_CC_2/1.3.6.1.4.1.9...
# 485   Calc-Training_P_00600_LEFT_MLO_2/1.3.6.1.4.1.9...
# 484   Calc-Training_P_00600_LEFT_MLO_1/1.3.6.1.4.1.9...
# 483   Calc-Training_P_00600_LEFT_CC_2/1.3.6.1.4.1.95...
# 482   Calc-Training_P_00600_LEFT_CC_1/1.3.6.1.4.1.95...
# 679   Calc-Training_P_00858_LEFT_CC_1/1.3.6.1.4.1.95...
# 680   Calc-Training_P_00858_LEFT_MLO_1/1.3.6.1.4.1.9...
# 681   Calc-Training_P_00858_RIGHT_CC_1/1.3.6.1.4.1.9...
# 682   Calc-Training_P_00858_RIGHT_CC_2/1.3.6.1.4.1.9...
# 683   Calc-Training_P_00858_RIGHT_MLO_1/1.3.6.1.4.1....
# 684   Calc-Training_P_00858_RIGHT_MLO_2/1.3.6.1.4.1....
# 735   Calc-Training_P_00937_LEFT_CC_1/1.3.6.1.4.1.95...
# 736   Calc-Training_P_00937_LEFT_MLO_1/1.3.6.1.4.1.9...
# 737   Calc-Training_P_00937_RIGHT_CC_1/1.3.6.1.4.1.9...
# ...                                                 ...
# 779   Calc-Training_P_00992_RIGHT_MLO_1/1.3.6.1.4.1....
# 899   Calc-Training_P_01156_LEFT_CC_1/1.3.6.1.4.1.95...
# 900   Calc-Training_P_01156_LEFT_MLO_1/1.3.6.1.4.1.9...
# 901   Calc-Training_P_01156_RIGHT_CC_1/1.3.6.1.4.1.9...
# 902   Calc-Training_P_01156_RIGHT_MLO_1/1.3.6.1.4.1....
# 940   Calc-Training_P_01200_RIGHT_MLO_1/1.3.6.1.4.1....
# 938   Calc-Training_P_01200_LEFT_CC_1/1.3.6.1.4.1.95...
# 939   Calc-Training_P_01200_LEFT_MLO_1/1.3.6.1.4.1.9...
# 981   Calc-Training_P_01276_LEFT_CC_1/1.3.6.1.4.1.95...
# 982   Calc-Training_P_01276_LEFT_MLO_1/1.3.6.1.4.1.9...
# 983   Calc-Training_P_01276_RIGHT_CC_1/1.3.6.1.4.1.9...
# 984   Calc-Training_P_01276_RIGHT_CC_2/1.3.6.1.4.1.9...
# 985   Calc-Training_P_01276_RIGHT_MLO_1/1.3.6.1.4.1....
# 986   Calc-Training_P_01276_RIGHT_MLO_2/1.3.6.1.4.1....
# 987   Calc-Training_P_01284_RIGHT_MLO_1/1.3.6.1.4.1....
# 988   Calc-Training_P_01284_RIGHT_MLO_2/1.3.6.1.4.1....
# 1101  Calc-Training_P_01409_LEFT_CC_1/1.3.6.1.4.1.95...
# 1102  Calc-Training_P_01409_LEFT_CC_2/1.3.6.1.4.1.95...
# 1103  Calc-Training_P_01409_LEFT_MLO_1/1.3.6.1.4.1.9...
# 1104  Calc-Training_P_01409_LEFT_MLO_2/1.3.6.1.4.1.9...
# 1105  Calc-Training_P_01409_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1106  Calc-Training_P_01409_RIGHT_MLO_1/1.3.6.1.4.1....
# 1244  Calc-Training_P_01582_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1245  Calc-Training_P_01582_RIGHT_MLO_1/1.3.6.1.4.1....
# 1243  Calc-Training_P_01582_LEFT_MLO_1/1.3.6.1.4.1.9...
# 1242  Calc-Training_P_01582_LEFT_CC_1/1.3.6.1.4.1.95...
# 1385  Calc-Training_P_01819_LEFT_MLO_1/1.3.6.1.4.1.9...
# 1383  Calc-Training_P_01819_LEFT_CC_1/1.3.6.1.4.1.95...
# 1384  Calc-Training_P_01819_LEFT_CC_2/1.3.6.1.4.1.95...
# 1386  Calc-Training_P_01819_LEFT_MLO_2/1.3.6.1.4.1.9...
#
# [66 rows x 14 columns]

# %%
multi_path_cal['patient_id'].nunique()
# Out:
# 14

# %%
multi_path_cal.groupby('patient_id')['pathology'].nunique()
# Out:
# patient_id
# P_00418    2
# P_00467    2
# P_00557    2
# P_00600    2
# P_00858    2
# P_00937    2
# P_00992    2
# P_01156    2
# P_01200    2
# P_01276    2
# P_01284    2
# P_01409    2
# P_01582    2
# P_01819    2
# Name: pathology, dtype: int64

# %% [markdown]
# **Note 1:**
# - There are 14 patients from Calcification train with more than 1 pathology so we can just leave these cases out.
# - For these 14 patients, sometimes it is because they have biopsy for left and right breasts, each has a different pathology. Sometimes, on the same breast, some patient (e.g., P_00600) has both pathologies.

# %% [markdown]
# # Mass Train

# %%
mass_train_desc.sort_values(by = 'patient_id', inplace = True)

# %%
mass_train_desc['patient_id'].nunique()
# Out:
# 691

# %%
mass_train_desc.shape
# Out:
# (1318, 14)

# %%
columns = ['image view', 'abnormality id', 'abnormality type', 'mass shape', 'mass margins', 'assessment', 'pathology',
      'subtlety']

# %%
for col in columns: 
    print('---------------')
    print('Unique values of column {}'.format(col))
    print(mass_train_desc[col].value_counts())
# Out:
# ---------------
# Unique values of column image view
# MLO    711
# CC     607
# Name: image view, dtype: int64
# ---------------
# Unique values of column abnormality id
# 1    1216
# 2      68
# 3      23
# 4       7
# 6       2
# 5       2
# Name: abnormality id, dtype: int64
# ---------------
# Unique values of column abnormality type
# mass    1318
# Name: abnormality type, dtype: int64
# ---------------
# Unique values of column mass shape
# IRREGULAR                                   351
# OVAL                                        321
# LOBULATED                                   305
# ROUND                                       123
# ARCHITECTURAL_DISTORTION                     80
# IRREGULAR-ARCHITECTURAL_DISTORTION           45
# LYMPH_NODE                                   26
# ASYMMETRIC_BREAST_TISSUE                     20
# FOCAL_ASYMMETRIC_DENSITY                     19
# OVAL-LYMPH_NODE                               6
# LOBULATED-IRREGULAR                           5
# LOBULATED-LYMPH_NODE                          3
# ROUND-OVAL                                    3
# IRREGULAR-FOCAL_ASYMMETRIC_DENSITY            2
# LOBULATED-ARCHITECTURAL_DISTORTION            2
# ROUND-LOBULATED                               1
# ROUND-IRREGULAR-ARCHITECTURAL_DISTORTION      1
# LOBULATED-OVAL                                1
# Name: mass shape, dtype: int64
# ---------------
# Unique values of column mass margins
# CIRCUMSCRIBED                            305
# SPICULATED                               281
# ILL_DEFINED                              278
# OBSCURED                                 197
# MICROLOBULATED                           108
# CIRCUMSCRIBED-ILL_DEFINED                 27
# ILL_DEFINED-SPICULATED                    25
# CIRCUMSCRIBED-OBSCURED                    19
# OBSCURED-ILL_DEFINED                      19
# OBSCURED-SPICULATED                        4
# OBSCURED-ILL_DEFINED-SPICULATED            4
# MICROLOBULATED-ILL_DEFINED                 3
# MICROLOBULATED-SPICULATED                  2
# MICROLOBULATED-ILL_DEFINED-SPICULATED      2
# CIRCUMSCRIBED-MICROLOBULATED               1
# Name: mass margins, dtype: int64
# ---------------
# Unique values of column assessment
# 4    533
# 5    299
# 3    279
# 0    129
# 2     77
# 1      1
# Name: assessment, dtype: int64
# ---------------
# Unique values of column pathology
# MALIGNANT                  637
# BENIGN                     577
# BENIGN_WITHOUT_CALLBACK    104
# Name: pathology, dtype: int64
# ---------------
# Unique values of column subtlety
# 5    543
# 4    375
# 3    257
# 2    100
# 1     41
# 0      2
# Name: subtlety, dtype: int64

# %%
multi_path_mass = mass_train_desc.groupby('patient_id').filter(lambda x: x['pathology'].nunique()> 1)

# %%
multi_path_mass['patient_id'].nunique()
# Out:
# 13

# %% [markdown]
# ### Check if every patient has both mass and cal images

# %%
cal_patient = cal_train_desc['patient_id'].unique().tolist()
mass_patient = mass_train_desc['patient_id'].unique().tolist()

# %%
print('Number of patients with cal images: {}'.format(len(cal_patient)))
print('Number of patients with mass images: {}'.format(len(mass_patient))) 
print('Number of patients that are in one list but not other {}'.format(len(np.setdiff1d(cal_patient, mass_patient).tolist())))
print('Number of patients that are in both lists {}'.format(len(set(cal_patient).intersection(set(mass_patient)))))
# Out:
# Number of patients with cal images: 602
# Number of patients with mass images: 691
# Number of patients that are in one list but not other 557
# Number of patients that are in both lists 45
